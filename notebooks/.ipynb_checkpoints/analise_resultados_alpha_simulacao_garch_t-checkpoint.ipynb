# %%
#Importando dados excel
import os
cwd = os.getcwd()
cwd
os.chdir('/Users/luizbezerra/Desktop/git/notebooks/')

# %%
import pandas as pd
file = 'estudo_simulacao_garch_t.xlsx'
xl = pd.ExcelFile(file)
df1 = xl.parse('alpha')

# %%
df1.head(15)
# Out:
#     alpha.garch  alpha.garch.t  alpha.gas  alpha.gas.t  alpha.gas.sp  \
# 0      0.095225       0.103599   0.052767     0.084390      0.093330
# 1      0.093172       0.100736   0.063961     0.081803      0.116435
# 2      0.101802       0.114273   0.063031     0.094765      0.128969
# 3      0.185732       0.141628   0.120282     0.107372      0.185333
# 4      0.058211       0.054068   0.045818     0.048369      0.063789
# 5      0.109262       0.100828   0.066747     0.087457      0.081184
# 6      0.104235       0.087510   0.058436     0.073950      0.085346
# 7      0.073994       0.091117   0.050528     0.075550      0.105724
# 8      0.099851       0.107919   0.073049     0.087256      0.100167
# 9      0.166720       0.119991   0.090088     0.093381      0.162810
# 10     0.048900       0.063571   0.036035     0.057944      0.061900
# 11     0.065281       0.073456   0.043764     0.063214      0.069173
# 12     0.134424       0.134602   0.071313     0.102034      0.123250
# 13     0.121092       0.148963   0.071050     0.104466      0.111510
# 14     0.122214       0.122657   0.065689     0.104227      0.097019
#
#     alpha.gas.st
# 0       0.097963
# 1       0.107540
# 2       0.102968
# 3       0.127231
# 4       0.048725
# 5       0.086052
# 6       0.079787
# 7       0.085695
# 8       0.108951
# 9       0.097299
# 10      0.056019
# 11      0.064003
# 12      0.108333
# 13      0.114377
# 14      0.107841

# %%
df1.mean()
# Out:
# alpha.garch      0.101501
# alpha.garch.t    0.101186
# alpha.gas        0.064795
# alpha.gas.t      0.083894
# alpha.gas.sp     0.101706
# alpha.gas.st     0.092165
# dtype: float64

# %%
df1.var()
# Out:
# alpha.garch      0.000770
# alpha.garch.t    0.000408
# alpha.gas        0.000238
# alpha.gas.t      0.000195
# alpha.gas.sp     0.000819
# alpha.gas.st     0.000406
# dtype: float64

# %%
import pandas as pd
import numpy as np
import pandas as pd
from scipy import stats, integrate
import seaborn as sns
import matplotlib.pyplot as plt
import os
import warnings

sns.set(color_codes=True)
np.random.seed(sum(map(ord, "distributions")))
names = df1.columns.values
#for i in range(0,6,1): 
    #x = df1[[i]]
    #x = np.array(x)      
    #x = x.flatten()           
    #sns.kdeplot(x, bw=.05, label=names[i])
    #sns.distplot(x, hist = False, label=names[i]);
#plt.axvline(x=0.85)

# %%
df1.plot(kind="kde",legend = True, figsize = (20,10))
plt.axvline(x=0.1, ls = 'dashed')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
d = ({})
names = df1.columns.values
for i in range(0,6,1): 
    x = df1[[i]]
    x = np.array(x)      
    x = x.flatten()
    rms = sqrt(mean_squared_error(np.repeat(0.10,len(x)), x))
    d.update({names[i]: rms})

# %%
df = pd.DataFrame(d, index=['RMSE'])
df
# Out:
#       alpha.garch  alpha.garch.t  alpha.gas  alpha.gas.sp  alpha.gas.st  \
# RMSE      0.02777        0.02022   0.038428      0.028638        0.0216
#
#       alpha.gas.t
# RMSE     0.021298
