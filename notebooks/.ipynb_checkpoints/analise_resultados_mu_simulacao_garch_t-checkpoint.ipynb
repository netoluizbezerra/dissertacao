# %%
#Importando dados excel
import os
cwd = os.getcwd()
cwd
os.chdir('/Users/luizbezerra/Desktop/git/notebooks/')

# %%
import pandas as pd
file = 'estudo_simulacao_garch_t.xlsx'
xl = pd.ExcelFile(file)
df1 = xl.parse('mu')

# %%
df1.head(15)
# Out:
#     mu.garch  mu.garch.t    mu.gas  mu.gas.t  mu.gas.sp  mu.gas.st
# 0  -0.015461    0.081978 -0.024622  0.079273  -0.054233   0.030687
# 1  -0.036757   -0.031054 -0.023153 -0.063889  -0.012152  -0.063080
# 2  -0.049313   -0.006093 -0.044243 -0.009978   0.051137  -0.002719
# 3  -0.169393   -0.213568 -0.192054 -0.200906  -0.219139  -0.220633
# 4  -0.041342   -0.049463 -0.029810 -0.057760  -0.079483  -0.067020
# 5   0.126566    0.034145  0.128359  0.031534   0.091097   0.070511
# 6  -0.031755    0.070027 -0.035090  0.058174   0.034362   0.007417
# 7   0.084745    0.050131  0.074543  0.046861   0.102514   0.090914
# 8  -0.098275   -0.098275 -0.247044 -0.166920  -0.104027  -0.154134
# 9  -0.142737   -0.043070 -0.144570 -0.072137  -0.186925  -0.136649
# 10 -0.073431   -0.114313 -0.070101 -0.122062  -0.070560  -0.064996
# 11 -0.086155   -0.098002 -0.082355 -0.110141  -0.145357  -0.100214
# 12  0.133816    0.124983  0.134590  0.112087   0.088504   0.081146
# 13 -0.194895   -0.165123 -0.141463 -0.187881  -0.155908  -0.177958
# 14 -0.061403    0.006614 -0.079343  0.000061  -0.091087  -0.074333

# %%
df1.mean()
# Out:
# mu.garch     -0.005849
# mu.garch.t   -0.008275
# mu.gas       -0.007212
# mu.gas.t     -0.008194
# mu.gas.sp    -0.007092
# mu.gas.st    -0.008553
# dtype: float64

# %%
df1.var()
# Out:
# mu.garch      0.015174
# mu.garch.t    0.011456
# mu.gas        0.015757
# mu.gas.t      0.011714
# mu.gas.sp     0.015198
# mu.gas.st     0.014336
# dtype: float64

# %%
import pandas as pd
import numpy as np
import pandas as pd
from scipy import stats, integrate
import seaborn as sns
import matplotlib.pyplot as plt
import os
import warnings

sns.set(color_codes=True)
np.random.seed(sum(map(ord, "distributions")))
names = df1.columns.values
#for i in range(0,6,1): 
    #x = df1[[i]]
    #x = np.array(x)      
    #x = x.flatten()           
    #sns.kdeplot(x, bw=.05, label=names[i])
    #sns.distplot(x, hist = False, label=names[i]);
#plt.axvline(x=0.85)

# %%
df1.plot(kind="kde",legend = True, figsize = (20,10))
plt.axvline(x=0, ls = 'dashed')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
d = ({})
names = df1.columns.values
for i in range(0,6,1): 
    x = df1[[i]]
    x = np.array(x)      
    x = x.flatten()
    rms = sqrt(mean_squared_error(np.repeat(0,len(x)), x))
    d.update({names[i]: rms})

# %%
df = pd.DataFrame(d, index=['RMSE'])
df
# Out:
#       mu.garch  mu.garch.t    mu.gas  mu.gas.sp  mu.gas.st  mu.gas.t
# RMSE  0.123208    0.107256  0.125619    0.12337   0.119931  0.108443
