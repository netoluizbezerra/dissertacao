# %%
#Importando dados excel
import os
cwd = os.getcwd()
cwd
os.chdir('/Users/luizbezerra/Desktop/git/notebooks/')

# %%
import pandas as pd
file = 'estudo_simulacao_garch_t.xlsx'
xl = pd.ExcelFile(file)
df1 = xl.parse('alpha')

# %%
df1.head(15)
# Out:
#     $\alpha$ Garch  $\alpha$ Garch(t)  $\alpha$  Gas(n)  $\alpha$  Gas(t)  \
# 0         0.095225           0.103599          0.052767          0.084390
# 1         0.093172           0.100736          0.063961          0.081803
# 2         0.101802           0.114273          0.063031          0.094765
# 3         0.185732           0.141628          0.120282          0.107372
# 4         0.058211           0.054068          0.045818          0.048369
# 5         0.109262           0.100828          0.066747          0.087457
# 6         0.104235           0.087510          0.058436          0.073950
# 7         0.073994           0.091117          0.050528          0.075550
# 8         0.099851           0.107919          0.073049          0.087256
# 9         0.166720           0.119991          0.090088          0.093381
# 10        0.048900           0.063571          0.036035          0.057944
# 11        0.065281           0.073456          0.043764          0.063214
# 12        0.134424           0.134602          0.071313          0.102034
# 13        0.121092           0.148963          0.071050          0.104466
# 14        0.122214           0.122657          0.065689          0.104227
#
#     $\alpha$ GAS(k-n)   $\alpha$ GAS(k-t)
# 0             0.093330           0.097963
# 1             0.116435           0.107540
# 2             0.128969           0.102968
# 3             0.185333           0.127231
# 4             0.063789           0.048725
# 5             0.081184           0.086052
# 6             0.085346           0.079787
# 7             0.105724           0.085695
# 8             0.100167           0.108951
# 9             0.162810           0.097299
# 10            0.061900           0.056019
# 11            0.069173           0.064003
# 12            0.123250           0.108333
# 13            0.111510           0.114377
# 14            0.097019           0.107841

# %%
df1.mean()
# Out:
# $\alpha$ Garch        0.101501
# $\alpha$ Garch(t)     0.101186
# $\alpha$  Gas(n)      0.064795
# $\alpha$  Gas(t)      0.083894
# $\alpha$ GAS(k-n)     0.101706
# $\alpha$ GAS(k-t)     0.092165
# dtype: float64

# %%
df1.var()
# Out:
# $\alpha$ Garch        0.000770
# $\alpha$ Garch(t)     0.000408
# $\alpha$  Gas(n)      0.000238
# $\alpha$  Gas(t)      0.000195
# $\alpha$ GAS(k-n)     0.000819
# $\alpha$ GAS(k-t)     0.000406
# dtype: float64

# %%
import pandas as pd
import numpy as np
import pandas as pd
from scipy import stats, integrate
import seaborn as sns
import matplotlib.pyplot as plt
import os
import warnings

sns.set(color_codes=True)
np.random.seed(sum(map(ord, "distributions")))
names = df1.columns.values
#for i in range(0,6,1): 
    #x = df1[[i]]
    #x = np.array(x)      
    #x = x.flatten()           
    #sns.kdeplot(x, bw=.05, label=names[i])
    #sns.distplot(x, hist = False, label=names[i]);
#plt.axvline(x=0.85)

# %%
df1.plot(kind="kde",legend = True, figsize = (20,10))
plt.axvline(x=0.1, ls = 'dashed')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
d = ({})
names = df1.columns.values
for i in range(0,6,1): 
    x = df1[[i]]
    x = np.array(x)      
    x = x.flatten()
    rms = sqrt(mean_squared_error(np.repeat(0.10,len(x)), x))
    d.update({names[i]: rms})

# %%
df = pd.DataFrame(d, index=['RMSE'])
df
# Out:
#       $\alpha$  Gas(n)  $\alpha$  Gas(t)  $\alpha$ GAS(k-n)   \
# RMSE          0.038428          0.021298            0.028638
#
#       $\alpha$ GAS(k-t)  $\alpha$ Garch  $\alpha$ Garch(t)
# RMSE             0.0216         0.02777            0.02022
