# %%
#Importando dados excel
import os
cwd = os.getcwd()
cwd
os.chdir('/Users/luizbezerra/Desktop/git/notebooks/')

# %%
import pandas as pd
file = 'estudo_simulacao_garch_t.xlsx'
xl = pd.ExcelFile(file)
df1 = xl.parse('beta')

# %%
df1.head(15)
# Out:
#     $\beta$ GARCH(st)  $\beta$ GARCH(t)  $\beta$ GAS(n)  $\beta$ GAS(t)  \
# 0            0.825275          0.850307        0.867263        0.853653
# 1            0.865184          0.851298        0.899231        0.877299
# 2            0.851513          0.843739        0.883558        0.846737
# 3            0.728324          0.798124        0.771692        0.819396
# 4            0.927356          0.929039        0.934567        0.933439
# 5            0.838608          0.844121        0.877254        0.856182
# 6            0.842830          0.866851        0.897713        0.891633
# 7            0.864330          0.848332        0.896915        0.860257
# 8            0.834829          0.851335        0.864942        0.846606
# 9            0.817708          0.845160        0.855914        0.865324
# 10           0.844009          0.872660        0.877082        0.859781
# 11           0.906729          0.896861        0.928489        0.905028
# 12           0.752140          0.798195        0.829328        0.814468
# 13           0.794800          0.791032        0.849167        0.820572
# 14           0.827364          0.812805        0.888609        0.824346
#
#     $\beta$ GAS(k-n)   $\beta$ GAS(k-t)
# 0            0.807903          0.819274
# 1            0.843515          0.826854
# 2            0.804141          0.848952
# 3            0.689636          0.783873
# 4            0.917198          0.917803
# 5            0.872869          0.830859
# 6            0.871611          0.878783
# 7            0.812561          0.851986
# 8            0.838549          0.826227
# 9            0.784687          0.836764
# 10           0.867054          0.852396
# 11           0.903005          0.900723
# 12           0.798939          0.790881
# 13           0.818789          0.786221
# 14           0.847514          0.802515

# %%
df1.mean()
# Out:
# $\beta$ GARCH(st)    0.841433
# $\beta$ GARCH(t)     0.844421
# $\beta$ GAS(n)       0.874883
# $\beta$ GAS(t)       0.855219
# $\beta$ GAS(k-n)     0.837637
# $\beta$ GAS(k-t)     0.835344
# dtype: float64

# %%
df1.var()
# Out:
# $\beta$ GARCH(st)    0.001653
# $\beta$ GARCH(t)     0.000932
# $\beta$ GAS(n)       0.001066
# $\beta$ GAS(t)       0.000829
# $\beta$ GAS(k-n)     0.002340
# $\beta$ GAS(k-t)     0.001376
# dtype: float64

# %%
import pandas as pd
import numpy as np
import pandas as pd
from scipy import stats, integrate
import seaborn as sns
import matplotlib.pyplot as plt
import os
import warnings

sns.set(color_codes=True)
np.random.seed(sum(map(ord, "distributions")))
names = df1.columns.values
#for i in range(0,6,1): 
    #x = df1[[i]]
    #x = np.array(x)      
    #x = x.flatten()           
    #sns.kdeplot(x, bw=.05, label=names[i])
    #sns.distplot(x, hist = False, label=names[i]);
#plt.axvline(x=0.85)

# %%
df1.plot(kind="kde",legend = True, figsize = (20,10))
plt.axvline(x=0.85, ls = 'dashed')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
d = ({})
names = df1.columns.values
for i in range(0,6,1): 
    x = df1[[i]]
    x = np.array(x)      
    x = x.flatten()
    rms = sqrt(mean_squared_error(np.repeat(0.85,len(x)), x))
    d.update({names[i]: rms})

# %%
df = pd.DataFrame(d, index=['RMSE'])
df
# Out:
#       $\beta$ GARCH(st)  $\beta$ GARCH(t)  $\beta$ GAS(k-n)   \
# RMSE           0.041515             0.031           0.049888
#
#       $\beta$ GAS(k-t)  $\beta$ GAS(n)  $\beta$ GAS(t)
# RMSE          0.039852        0.041027        0.029227
