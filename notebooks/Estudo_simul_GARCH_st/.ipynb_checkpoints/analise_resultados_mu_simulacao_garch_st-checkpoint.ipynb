# %%
#Importando dados excel
import os
cwd = os.getcwd()
cwd
os.chdir('/Users/luizbezerra/Desktop/git/notebooks/')

# %%
import pandas as pd
file = 'estudo_simulacao_garch_st.xlsx'
xl = pd.ExcelFile(file)
df1 = xl.parse('mu')

# %%
df1.head(15)
# Out:
#           mu  mu.garch.t  mu.garch.st    mu.gas  mu.gas.t  mu.gas.st  \
# 0   0.081723    0.440429     0.061208  0.086807  0.448593   0.085408
# 1   0.042372    0.353550     0.016453  0.035368  0.350719  -0.002709
# 2   0.010296    0.242886    -0.000972  0.001678  0.245973   0.038950
# 3  -0.065233    0.347910    -0.066201 -0.093984  0.331112  -0.056599
# 4   0.081371    0.393065     0.060700  0.070772  0.378838   0.091889
# 5   0.079826    0.327626     0.044556  0.078951  0.315914   0.072473
# 6  -0.041714    0.248480    -0.097340 -0.036127  0.215332  -0.209441
# 7  -0.059762    0.231982    -0.108006 -0.070301  0.212056  -0.042600
# 8   0.205810    0.442163     0.148333  0.177629  0.443858   0.225462
# 9   0.099150    0.302358     0.031741  0.160040  0.288047   0.216356
# 10 -0.004331    0.313288    -0.045099 -0.035206  0.288611  -0.125245
# 11 -0.234316    0.205246    -0.217987 -0.213922  0.166467  -0.203143
# 12  0.108257    0.562782     0.168331  0.127988  0.526687   0.174158
# 13  0.029290    0.252643     0.009621  0.019452  0.234937   0.070346
# 14  0.030129    0.162475     0.003899  0.026475  0.413611  -0.047171
#
#     mu.gas.st.1
# 0      0.188343
# 1      0.130575
# 2      0.101590
# 3      0.009324
# 4      0.136283
# 5      0.120320
# 6      0.025609
# 7      0.041803
# 8      0.264389
# 9      0.175181
# 10     0.097232
# 11    -0.144247
# 12     0.228662
# 13     0.127253
# 14     0.100139

# %%
df1.mean()
# Out:
# mu             0.003848
# mu.garch.t     0.302956
# mu.garch.st   -0.002098
# mu.gas         0.001152
# mu.gas.t       0.317623
# mu.gas.st      0.026144
# mu.gas.st.1    0.106685
# dtype: float64

# %%
df1.var()
# Out:
# mu             0.015056
# mu.garch.t     0.017062
# mu.garch.st    0.013869
# mu.gas         0.015457
# mu.gas.t       0.012532
# mu.gas.st      0.017185
# mu.gas.st.1    0.015337
# dtype: float64

# %%
import pandas as pd
import numpy as np
import pandas as pd
from scipy import stats, integrate
import seaborn as sns
import matplotlib.pyplot as plt
import os
import warnings

sns.set(color_codes=True)
np.random.seed(sum(map(ord, "distributions")))
names = df1.columns.values
#for i in range(0,6,1): 
    #x = df1[[i]]
    #x = np.array(x)      
    #x = x.flatten()           
    #sns.kdeplot(x, bw=.05, label=names[i])
    #sns.distplot(x, hist = False, label=names[i]);
#plt.axvline(x=0.85)

# %%
df1.plot(kind="kde",legend = True, figsize = (20,10))
plt.axvline(x=0, ls = 'dashed')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
d = ({})
names = df1.columns.values
for i in range(0,7,1): 
    x = df1[[i]]
    x = np.array(x)      
    x = x.flatten()
    rms = sqrt(mean_squared_error(np.repeat(0,len(x)), x))
    d.update({names[i]: rms})

# %%
df = pd.DataFrame(d, index=['RMSE'])
df
# Out:
#             mu  mu.garch.st  mu.garch.t    mu.gas  mu.gas.st  mu.gas.st.1  \
# RMSE  0.122638     0.117668    0.329864  0.124207   0.133542     0.163365
#
#       mu.gas.t
# RMSE  0.336736
