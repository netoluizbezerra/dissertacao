# %%
#Importando dados excel
import os
cwd = os.getcwd()
cwd
os.chdir('/Users/luizbezerra/Desktop/git/notebooks/')

# %%
import pandas as pd
file = 'estudo_simulacao_garch_st.xlsx'
xl = pd.ExcelFile(file)
df1 = xl.parse('beta')

# %%
df1.head(15)
# Out:
#     $\beta$ GARCH(st)  $\beta$ GARCH(t)  $\beta$ Garch(st)  $\beta$ GAS(n)  \
# 0            0.897766          0.876689           0.863759        0.921775
# 1            0.892496          0.850039           0.845818        0.919446
# 2            0.851627          0.818909           0.826051        0.875212
# 3            0.837320          0.809619           0.822582        0.869583
# 4            0.824240          0.810150           0.812888        0.832166
# 5            0.909111          0.916741           0.899094        0.911377
# 6            0.762884          0.825572           0.841009        0.928125
# 7            0.876878          0.849888           0.850907        0.898055
# 8            0.862101          0.816511           0.817742        0.900430
# 9            0.885828          0.870409           0.869494        0.904584
# 10           0.857691          0.866447           0.848176        0.889278
# 11           0.855148          0.862469           0.861481        0.893092
# 12           0.855826          0.883579           0.880604        0.883397
# 13           0.839426          0.839985           0.840309        0.873883
# 14           0.830621          0.827651           0.829152        0.885119
#
#     $\beta$ GAS(t)  $\beta$ GAS(k-n)   $\beta$ GAS(k-t)
# 0         0.894538           0.883891          0.912112
# 1         0.853128           0.877001          0.848955
# 2         0.837191           0.848234          0.829986
# 3         0.827686           0.802344          0.821049
# 4         0.842988           0.822873          0.831135
# 5         0.918597           0.893757          0.880164
# 6         0.860768           0.897126          0.852946
# 7         0.859905           0.873412          0.858660
# 8         0.856204           0.882393          0.832796
# 9         0.880503           0.874037          0.871334
# 10        0.881471           0.912417          0.833344
# 11        0.884990           0.814131          0.880340
# 12        0.871234           0.741044          0.877194
# 13        0.861739           0.844686          0.841537
# 14        0.828415           0.793752          0.811556

# %%
df1.mean()
# Out:
# $\beta$ GARCH(st)    0.840549
# $\beta$ GARCH(t)     0.847560
# $\beta$ Garch(st)    0.846536
# $\beta$ GAS(n)       0.876455
# $\beta$ GAS(t)       0.856996
# $\beta$ GAS(k-n)     0.839991
# $\beta$ GAS(k-t)     0.838146
# dtype: float64

# %%
df1.var()
# Out:
# $\beta$ GARCH(st)    0.001673
# $\beta$ GARCH(t)     0.000728
# $\beta$ Garch(st)    0.000679
# $\beta$ GAS(n)       0.001245
# $\beta$ GAS(t)       0.000683
# $\beta$ GAS(k-n)     0.001947
# $\beta$ GAS(k-t)     0.001319
# dtype: float64

# %%
import pandas as pd
import numpy as np
import pandas as pd
from scipy import stats, integrate
import seaborn as sns
import matplotlib.pyplot as plt
import os
import warnings

sns.set(color_codes=True)
np.random.seed(sum(map(ord, "distributions")))
names = df1.columns.values
#for i in range(0,6,1): 
    #x = df1[[i]]
    #x = np.array(x)      
    #x = x.flatten()           
    #sns.kdeplot(x, bw=.05, label=names[i])
    #sns.distplot(x, hist = False, label=names[i]);
#plt.axvline(x=0.85)

# %%
df1.plot(kind="kde",legend = True, figsize = (20,10))
plt.axvline(x=0.85, ls = 'dashed')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
d = ({})
names = df1.columns.values
for i in range(0,7,1): 
    x = df1[[i]]
    x = np.array(x)      
    x = x.flatten()
    rms = sqrt(mean_squared_error(np.repeat(0.85,len(x)), x))
    d.update({names[i]: rms})

# %%
df = pd.DataFrame(d, index=['RMSE'])
df
# Out:
#       $\beta$ GARCH(st)  $\beta$ GARCH(t)  $\beta$ GAS(k-n)   \
# RMSE           0.041944          0.027058           0.045202
#
#       $\beta$ GAS(k-t)  $\beta$ GAS(n)  $\beta$ GAS(t)  $\beta$ Garch(st)
# RMSE          0.038168        0.044072        0.027033           0.026254
